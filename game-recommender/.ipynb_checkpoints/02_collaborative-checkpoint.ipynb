# %% [markdown]
# ### Cell 1 � Import all libraries

# %%
#%pip install scikit-surprise
# Out:
# ...
#      ---------------------------------------- 0.0/154.4 kB ? eta -:--:--
#      ---- -------------------------------- 20.5/154.4 kB 330.3 kB/s eta 0:00:01
#      ------- ----------------------------- 30.7/154.4 kB 220.2 kB/s eta 0:00:01
#      ------- ----------------------------- 30.7/154.4 kB 220.2 kB/s eta 0:00:01
#      -------------- ---------------------- 61.4/154.4 kB 299.4 kB/s eta 0:00:01
#      ---------------------- -------------- 92.2/154.4 kB 403.5 kB/s eta 0:00:01
#      ---------------------------- ------- 122.9/154.4 kB 450.6 kB/s eta 0:00:01
#      ------------------------------------ 154.4/154.4 kB 513.1 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
# ...

# %%
import pandas as pd
import numpy as np
from surprise import Dataset, Reader, SVD, accuracy
from surprise.model_selection import train_test_split
import pickle
import os

# %% [markdown]
# ### Cell 2 � Load interactions.csv

# %%
# Read interactions.csv
df = pd.read_csv('data/interactions.csv')
print("First 5 rows:")
print(df.head())
print("\nShape of dataframe:", df.shape)

# Create smaller dataframe with only player_id, item_id, rating
cf_data = df[['player_id', 'item_id', 'rating']]
print("\nShape of cf_data:", cf_data.shape)
# Out:
# First 5 rows:
#    player_id player_name  item_id         item_name category  rating  \
# 0          1    Player_1        2        Sniper AWM   Weapon       3
# 1          1    Player_1       48  Land at Hot Zone  Mission       2
# 2          1    Player_1       18     SMG Tommy Gun   Weapon       3
# 3          1    Player_1       16  Grenade Launcher   Weapon       5
# 4          1    Player_1       15    Sniper Mini-14   Weapon       2
#
#    play_style
# 0  aggressive
# 1  aggressive
# 2  aggressive
# 3  aggressive
# 4  aggressive
#
# Shape of dataframe: (688, 7)
#
# Shape of cf_data: (688, 3)

# %% [markdown]
# ### Cell 3 � Convert data to Surprise format

# %%
# Create a Reader object
reader = Reader(rating_scale=(1, 5))

# Convert pandas dataframe to Surprise dataset
data = Dataset.load_from_df(cf_data[['player_id', 'item_id', 'rating']], reader)
print("Data loaded successfully into Surprise format!")
# Out:
# Data loaded successfully into Surprise format!

# %% [markdown]
# ### Cell 4 � Split into train and test sets

# %%
# Split data: 80% train, 20% test
trainset, testset = train_test_split(data, test_size=0.20, random_state=42)

print(f"Number of interactions in trainset: {trainset.n_ratings}")
print(f"Number of interactions in testset: {len(testset)}")
# Out:
# Number of interactions in trainset: 550
# Number of interactions in testset: 138

# %% [markdown]
# ### Cell 5 � Train the SVD model

# %%
# Create SVD model
model = SVD(n_factors=50, n_epochs=20, random_state=42)

# Train the model
model.fit(trainset)
print("Model training complete!")
# Out:
# Model training complete!

# %% [markdown]
# ### Cell 6 � Calculate RMSE and MAE

# %%
# Make predictions on testset
predictions = model.test(testset)

# Calculate RMSE and MAE
rmse_score = accuracy.rmse(predictions, verbose=False)
mae_score = accuracy.mae(predictions, verbose=False)

print(f"RMSE Score: {rmse_score:.4f}")
print(f"MAE Score: {mae_score:.4f}")

if rmse_score < 1.0:
    print("RMSE is good (below 1.0)!")
else:
    print("RMSE needs improvement.")
# Out:
# RMSE Score: 1.1673
# MAE Score: 1.0330
# RMSE needs improvement.

# %% [markdown]
# ### Cell 7 � Build the recommendation function

# %%
# Load items data to get all item IDs
items_df = pd.read_csv('data/items.csv')
all_item_ids = items_df['item_id'].unique()

def get_cf_recommendations(player_id, n=5):
    # Get items already rated by this player
    rated_items = cf_data[cf_data['player_id'] == player_id]['item_id'].unique()
    
    # Get unseen items
    unseen_items = [item_id for item_id in all_item_ids if item_id not in rated_items]
    
    # Predict ratings for unseen items
    predictions_list = [model.predict(player_id, item_id) for item_id in unseen_items]
    
    # Sort predictions by predicted score (est) from highest to lowest
    predictions_list.sort(key=lambda x: x.est, reverse=True)
    
    # Return top N items
    top_n = predictions_list[:n]
    return [(pred.iid, pred.est) for pred in top_n]

# Test function with player_id=1
print("Recommendations for Player 1:")
print(get_cf_recommendations(player_id=1))
# Out:
# Recommendations for Player 1:
# [(25, 4.155088462006381), (31, 4.094468583398702), (39, 4.019917153687254), (17, 3.977300030042672), (8, 3.952507926053337)]

# %% [markdown]
# ### Cell 8 � Test the function on 3 players

# %%
# Load players data for play styles
players_df = pd.read_csv('data/players.csv')

# Test on Player 1, 25, 50
test_players = [1, 25, 50]

for p_id in test_players:
    play_style = players_df[players_df['player_id'] == p_id]['play_style'].values[0]
    print(f"\n--- Player {p_id} ({play_style}) ---")
    
    recs = get_cf_recommendations(p_id, n=5)
    for item_id, score in recs:
        item_info = items_df[items_df['item_id'] == item_id].iloc[0]
        item_name = item_info['item_name']
        item_cat = item_info['category']
        print(f"Score: {score:.2f} | {item_name} ({item_cat})")
# Out:
# --- Player 1 (aggressive) ---
# Score: 4.16 | Golden Warrior (Skin)
# Score: 4.09 | Zombie Survivor (Skin)
# Score: 4.02 | Vehicle Lava Buggy (Skin)
# Score: 3.98 | Rifle QBZ (Weapon)
# Score: 3.95 | Shotgun DBS (Weapon)
#
# --- Player 25 (support) ---
# Score: 4.24 | Vehicle Lava Buggy (Skin)
# Score: 4.23 | Zombie Survivor (Skin)
# Score: 4.21 | Golden Warrior (Skin)
# Score: 4.05 | Rifle QBZ (Weapon)
# Score: 4.02 | Helmet Crown (Skin)
#
# --- Player 50 (explorer) ---
# Score: 4.25 | Zombie Survivor (Skin)
# Score: 4.16 | Shotgun S12K (Weapon)
# Score: 4.14 | Golden Warrior (Skin)
# Score: 4.10 | Rifle QBZ (Weapon)
# Score: 4.09 | Vehicle Lava Buggy (Skin)

# %% [markdown]
# ### Cell 9 � Save results to cf_results.csv

# %%
# Generate recommendations for all 100 players
all_results = []
all_players = cf_data['player_id'].unique()

for p_id in all_players:
    recs = get_cf_recommendations(p_id, n=5)
    for rank, (item_id, score) in enumerate(recs, start=1):
        item_name = items_df[items_df['item_id'] == item_id]['item_name'].values[0]
        all_results.append({
            'player_id': p_id,
            'item_id': item_id,
            'item_name': item_name,
            'predicted_score': score,
            'rank': rank
        })

# Convert to DataFrame and save
results_df = pd.DataFrame(all_results)
os.makedirs('outputs', exist_ok=True)
results_df.to_csv('outputs/cf_results.csv', index=False)

print("First 10 rows of cf_results.csv:")
print(results_df.head(10))
# Out:
# First 10 rows of cf_results.csv:
#    player_id  item_id           item_name  predicted_score  rank
# 0          1       25      Golden Warrior         4.155088     1
# 1          1       31     Zombie Survivor         4.094469     2
# 2          1       39  Vehicle Lava Buggy         4.019917     3
# 3          1       17           Rifle QBZ         3.977300     4
# 4          1        8         Shotgun DBS         3.952508     5
# 5          2       25      Golden Warrior         4.148661     1
# 6          2       31     Zombie Survivor         4.127340     2
# 7          2       34   Robot Dance Emote         4.032893     3
# 8          2       17           Rifle QBZ         3.979179     4
# 9          2       38        Helmet Skull         3.935465     5

# %% [markdown]
# ### Cell 10 � Save the trained model

# %%
# Save model as cf_model.pkl
os.makedirs("models", exist_ok=True)
model_path = "models/cf_model.pkl"

with open(model_path, "wb") as file:
    pickle.dump(model, file)

print(f"File exists: {os.path.exists(model_path)}")
print(f"File size: {os.path.getsize(model_path) / 1024:.2f} KB")
# Out:
# File exists: True
# File size: 80.26 KB

# %% [markdown]
# ### Cell 11 � Final summary printout

# %%
print("="*40)
print("COLLABORATIVE FILTERING SUMMARY")
print("="*40)
print(f"RMSE Score: {rmse_score:.4f}")
print(f"MAE Score: {mae_score:.4f}")
print(f"Total players covered: {len(results_df['player_id'].unique())}")
print(f"Total recommendations generated: {len(results_df)}")
print("\nFiles created:")
print(f"- {model_path}")
print("- outputs/cf_results.csv")
print("\nSample recommendation for Player 1:")
p1_recs = results_df[results_df['player_id'] == 1]
for _, row in p1_recs.iterrows():
    print(f"  Rank {row['rank']}: {row['item_name']} (Score: {row['predicted_score']:.2f})")
print("="*40)
# Out:
# ...
# COLLABORATIVE FILTERING SUMMARY
# ...
# RMSE Score: 1.1673
# MAE Score: 1.0330
# Total players covered: 100
# Total recommendations generated: 500
#
# Files created:
# - models/cf_model.pkl
# - outputs/cf_results.csv
#
# Sample recommendation for Player 1:
#   Rank 1: Golden Warrior (Score: 4.16)
#   Rank 2: Zombie Survivor (Score: 4.09)
#   Rank 3: Vehicle Lava Buggy (Score: 4.02)
#   Rank 4: Rifle QBZ (Score: 3.98)
#   Rank 5: Shotgun DBS (Score: 3.95)
# ...
